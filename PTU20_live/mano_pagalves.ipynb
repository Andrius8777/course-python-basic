# %%
from PIL import Image



image = Image.open('ai_guy.webp')
new_size = (240, 240)
resized = image.resize(new_size)
resized.save('Naujas_pic.jpg')
resized
# Out:
# <PIL.Image.Image image mode=RGB size=240x240>
