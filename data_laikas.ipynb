# %%
from datetime import datetime

dabar = datetime.now()
format_string = "%M:%S"
laikas = dabar.strftime(format_string)
print(laikas)
# Out:
# 14:09

# %%
#uzd
from datetime import datetime, timedelta

def dienos_iki_gimtadienio(gimtadienis):
    gimtadienis_format = datetime.strptime(gimtadienis, '%Y-%m-%d')
    dabar = datetime.now()
    gimtadienio_data = gimtadienis_format.replace(year=dabar.year)

    if gimtadienio_data < dabar:
        gimtadienio_data = gimtadienio_data.replace(year=dabar.year + 1)

    skirtumas = gimtadienio_data - dabar
    return skirtumas.days  

gimtadienis = '2017-04-24'
print(f'Liko {dienos_iki_gimtadienio(gimtadienis)} dienos iki gimtadienio')
# Out:
# Liko 98 dienos iki gimtadienio

# %%
from datetime import datetime, timedelta

def prideti_48_valandas(data_laikas):
    format_string = "%Y-%m-%d %H:%M"
    date_object = datetime.strptime(data_laikas, format_string)
    naujas_date_object = date_object + timedelta(hours=48)
    naujas_data_laikas = naujas_date_object.strftime(format_string)
    return naujas_data_laikas

data_laikas = "2023-05-21 15:30"
print(f"Pridėjus 48 valandas: {prideti_48_valandas(data_laikas)}")
# Out:
# Pridėjus 48 valandas: 2023-05-23 15:30

# %%
from datetime import datetime, timedelta

def ketvirta_uzduotis(laikas1, laikas2):
    date_object1 = datetime.fromtimestamp(laikas1)
    date_object2 = datetime.fromtimestamp(laikas2)
    skirtumas = abs(date_object2 - date_object1)
    return skirtumas.days
laikas1 = 1654822466
laikas2 = 1786242544
print(f'Laikotarpiu skirtumas dienomis: {ketvirta_uzduotis(laikas1, laikas2)}')
# Out:
# Laikotarpiu skirtumas dienomis: 1521

# %%
from datetime import datetime

def savaites_diena(data):
    format_string = "%Y-%m-%d"
    date_object = datetime.strptime(data, format_string)
    dienos = ["Pirmadienis", "Antradienis", "Trečiadienis", "Ketvirtadienis", "Penktadienis", "Šeštadienis", "Sekmadienis"]
    return dienos[date_object.weekday()]

data = "2024-04-24"
print(f"Ši {data} data yra {savaites_diena(data)}")
# Out:
# Ši 2024-04-24 data yra Trečiadienis

# %%
from zoneinfo import ZoneInfo
from zoneinfo import available_timezones
for zone in available_timezones():
    print(zone)
# Out:
# Pacific/Guadalcanal
# Asia/Singapore
# America/Goose_Bay
# Pacific/Fakaofo
# US/Eastern
# Europe/Rome
# Pacific/Tahiti
# America/Cordoba
# Africa/Mbabane
# America/Araguaina
# America/Kralendijk
# GMT-0
# Europe/Tallinn
# Indian/Maldives
# America/Santiago
# Africa/Harare
# Pacific/Johnston
# Europe/Bratislava
# America/Cancun
# Canada/Eastern
# Asia/Famagusta
# Atlantic/Cape_Verde
# Pacific/Tarawa
# Australia/Victoria
# America/Louisville
# Europe/Zurich
# Eire
# PRC
# Africa/Asmera
# Asia/Dacca
# Pacific/Gambier
# Australia/LHI
# America/Buenos_Aires
# Europe/Zaporozhye
# Asia/Saigon
# America/Scoresbysund
# America/Martinique
# Indian/Antananarivo
# Etc/UCT
# America/Havana
# Africa/Dar_es_Salaam
# America/St_Barthelemy
# Canada/Mountain
# Pacific/Honolulu
# US/Indiana-Starke
# Europe/Riga
# Etc/GMT-8
# Asia/Chongqing
# Australia/Lord_Howe
# America/Porto_Velho
# Africa/Windhoek
# Etc/GMT-11
# Asia/Tomsk
# America/Nuuk
# Indian/Reunion
# Asia/Ho_Chi_Minh
# Africa/Kampala
# Asia/Dili
# America/Knox_IN
# Etc/Greenwich
# Atlantic/Stanley
# Asia/Baku
# Pacific/Ponape
# Asia/Taipei
# Pacific/Kwajalein
# Canada/Saskatchewan
# Asia/Damascus
# Etc/GMT-5
# America/Denver
# Australia/ACT
# Australia/Canberra
# Asia/Rangoon
# America/Yellowknife
# America/St_Lucia
# Pacific/Samoa
# Cuba
# Pacific/Pitcairn
# America/Indiana/Tell_City
# Pacific/Auckland
# Etc/GMT+2
# Australia/Adelaide
# Asia/Atyrau
# Africa/Lusaka
# Europe/Madrid
# Antarctica/South_Pole
# Universal
# America/Ensenada
# Europe/Minsk
# Europe/Lisbon
# America/Kentucky/Louisville
# Indian/Mauritius
# Pacific/Niue
# Indian/Cocos
# America/Anguilla
# Asia/Kuwait
# Asia/Seoul
# Asia/Phnom_Penh
# Etc/GMT-14
# Etc/GMT+0
# Antarctica/Palmer
# Asia/Vientiane
# Etc/GMT-9
# Europe/Belgrade
# Africa/Libreville
# Asia/Vladivostok
# Pacific/Galapagos
# Asia/Tbilisi
# Brazil/East
# Europe/Simferopol
# Africa/Monrovia
# America/Indiana/Vevay
# Europe/Monaco
# Mexico/General
# Africa/Ceuta
# America/Virgin
# Africa/Bujumbura
# America/Argentina/Mendoza
# Asia/Thimphu
# Etc/GMT-12
# Europe/Nicosia
# Libya
# America/Lima
# Atlantic/Jan_Mayen
# America/Iqaluit
# Pacific/Majuro
# America/Juneau
# America/Los_Angeles
# America/Fort_Wayne
# NZ
# GMT0
# America/Tortola
# Asia/Bishkek
# America/Porto_Acre
# Europe/Stockholm
# Atlantic/Canary
# Pacific/Noumea
# Iran
# Asia/Harbin
# Etc/GMT-2
# Africa/Banjul
# Asia/Hong_Kong
# Africa/Luanda
# America/Marigot
# America/Argentina/La_Rioja
# Europe/Berlin
# Asia/Urumqi
# America/Mendoza
# America/St_Kitts
# America/Rankin_Inlet
# Etc/GMT+12
# Europe/Malta
# Europe/Jersey
# ROK
# Asia/Macao
# Australia/Darwin
# Asia/Tokyo
# America/Phoenix
# America/Regina
# Asia/Nicosia
# Europe/Volgograd
# America/Eirunepe
# America/Indiana/Petersburg
# Europe/Ulyanovsk
# Africa/Kigali
# Asia/Samarkand
# America/Halifax
# America/Puerto_Rico
# America/Tijuana
# America/Indiana/Marengo
# America/Costa_Rica
# Antarctica/McMurdo
# Pacific/Tongatapu
# America/Managua
# Africa/Maseru
# America/Port_of_Spain
# Brazil/Acre
# Atlantic/Reykjavik
# Pacific/Funafuti
# America/Toronto
# America/Mexico_City
# Europe/Budapest
# America/Resolute
# America/Argentina/Jujuy
# America/Sitka
# Factory
# Antarctica/Casey
# Australia/Lindeman
# Africa/Algiers
# Asia/Aden
# CST6CDT
# America/Vancouver
# CET
# America/Nome
# Atlantic/Azores
# Africa/Gaborone
# Pacific/Kiritimati
# America/Cayman
# Asia/Ujung_Pandang
# Europe/Vienna
# America/Chihuahua
# Etc/GMT+5
# Asia/Yerevan
# Etc/GMT
# Etc/GMT+7
# Africa/Lome
# Africa/Cairo
# America/Lower_Princes
# US/Aleutian
# Kwajalein
# Asia/Almaty
# Europe/Ljubljana
# Europe/Oslo
# Africa/Maputo
# UTC
# Pacific/Wake
# Pacific/Easter
# Asia/Qostanay
# Australia/Tasmania
# Antarctica/Syowa
# Europe/Kyiv
# Jamaica
# America/Panama
# America/Caracas
# Asia/Srednekolymsk
# America/Boa_Vista
# Pacific/Saipan
# America/Guyana
# MST
# HST
# America/Fort_Nelson
# America/St_Johns
# Europe/Isle_of_Man
# America/Dominica
# Asia/Katmandu
# Indian/Mayotte
# America/Shiprock
# Asia/Kolkata
# America/Nipigon
# Australia/Currie
# America/Godthab
# Pacific/Marquesas
# Asia/Manila
# Africa/Douala
# Arctic/Longyearbyen
# W-SU
# America/Matamoros
# Africa/Timbuktu
# Asia/Colombo
# Antarctica/Macquarie
# Europe/Sofia
# Asia/Dushanbe
# Europe/Kirov
# Pacific/Midway
# GB-Eire
# Asia/Riyadh
# America/Jujuy
# America/Hermosillo
# Etc/GMT-0
# America/Guayaquil
# Antarctica/Rothera
# Hongkong
# Japan
# America/Cayenne
# America/Indianapolis
# Pacific/Efate
# Canada/Yukon
# Europe/Istanbul
# Australia/North
# America/Grand_Turk
# Asia/Thimbu
# Atlantic/South_Georgia
# Australia/Eucla
# Portugal
# America/Rosario
# Asia/Barnaul
# America/Argentina/San_Luis
# America/Metlakatla
# America/Kentucky/Monticello
# Asia/Tashkent
# America/Coral_Harbour
# America/Indiana/Knox
# America/La_Paz
# America/Sao_Paulo
# Asia/Brunei
# Asia/Aqtobe
# Asia/Qatar
# Europe/Warsaw
# Africa/Bissau
# Asia/Shanghai
# Europe/Tiraspol
# US/East-Indiana
# America/Recife
# Asia/Hovd
# Africa/Addis_Ababa
# Asia/Istanbul
# Asia/Gaza
# Europe/Skopje
# Antarctica/Davis
# Etc/GMT-7
# Africa/Accra
# Etc/GMT-4
# Asia/Yangon
# Asia/Kashgar
# Australia/West
# America/Antigua
# America/Pangnirtung
# Africa/Tunis
# Asia/Amman
# Europe/Busingen
# Asia/Yekaterinburg
# Asia/Choibalsan
# America/Glace_Bay
# Antarctica/Vostok
# America/Catamarca
# MST7MDT
# Africa/Malabo
# Africa/Lubumbashi
# Europe/San_Marino
# America/St_Thomas
# America/Santa_Isabel
# America/Montserrat
# America/Rainy_River
# Asia/Novosibirsk
# Africa/Casablanca
# America/Santo_Domingo
# Indian/Comoro
# NZ-CHAT
# Pacific/Yap
# America/Winnipeg
# Africa/Bamako
# America/Rio_Branco
# America/Atka
# Etc/GMT-1
# GB
# Etc/UTC
# Africa/Dakar
# Africa/Johannesburg
# America/Asuncion
# Etc/GMT+1
# Asia/Macau
# America/Montevideo
# Europe/Luxembourg
# Asia/Ulaanbaatar
# Asia/Sakhalin
# Etc/GMT+6
# Israel
# America/Whitehorse
# Europe/Vatican
# Asia/Calcutta
# America/Tegucigalpa
# Africa/Sao_Tome
# Atlantic/St_Helena
# EST5EDT
# Brazil/DeNoronha
# Etc/GMT-13
# GMT+0
# Asia/Dubai
# America/North_Dakota/New_Salem
# Pacific/Chuuk
# Singapore
# Etc/GMT-3
# Navajo
# America/Bogota
# Africa/Niamey
# Asia/Dhaka
# Pacific/Kanton
# Asia/Jakarta
# Indian/Christmas
# Africa/Djibouti
# Africa/Lagos
# Pacific/Nauru
# Europe/Vaduz
# Asia/Irkutsk
# US/Central
# Asia/Magadan
# America/Mazatlan
# Indian/Mahe
# America/Menominee
# Asia/Kathmandu
# Indian/Chagos
# America/Noronha
# Europe/Podgorica
# America/Barbados
# Europe/Chisinau
# Asia/Khandyga
# America/Monterrey
# America/Edmonton
# Australia/Queensland
# US/Michigan
# Asia/Makassar
# America/Port-au-Prince
# Asia/Ashgabat
# Pacific/Truk
# Chile/Continental
# Antarctica/DumontDUrville
# America/Manaus
# Pacific/Palau
# America/Nassau
# Asia/Tel_Aviv
# America/Danmarkshavn
# America/Cuiaba
# Africa/Blantyre
# Atlantic/Faroe
# Europe/Helsinki
# America/Argentina/Catamarca
# Etc/GMT-6
# Asia/Bahrain
# America/Grenada
# Asia/Krasnoyarsk
# Pacific/Enderbury
# Australia/Hobart
# Asia/Baghdad
# Canada/Pacific
# Africa/Conakry
# Pacific/Port_Moresby
# Asia/Ust-Nera
# US/Arizona
# America/Bahia_Banderas
# Asia/Kabul
# WET
# America/Belize
# Canada/Newfoundland
# Africa/Kinshasa
# Asia/Beirut
# America/Indiana/Indianapolis
# Europe/Sarajevo
# America/Argentina/Tucuman
# America/Jamaica
# Asia/Pontianak
# Asia/Qyzylorda
# Pacific/Rarotonga
# America/Creston
# Canada/Central
# Africa/Juba
# Africa/El_Aaiun
# Pacific/Pago_Pago
# Asia/Novokuznetsk
# EET
# Etc/GMT+3
# America/Boise
# Etc/GMT+9
# America/Campo_Grande
# America/Argentina/Cordoba
# Europe/Prague
# America/Paramaribo
# Etc/GMT-10
# Pacific/Bougainville
# America/Indiana/Vincennes
# America/Moncton
# Asia/Yakutsk
# Asia/Muscat
# Africa/Porto-Novo
# Europe/Copenhagen
# Asia/Jayapura
# Australia/Brisbane
# Asia/Ulan_Bator
# Asia/Kamchatka
# Europe/Tirane
# Europe/Guernsey
# Asia/Chita
# America/Chicago
# America/Argentina/San_Juan
# Africa/Tripoli
# Australia/NSW
# America/Merida
# Greenwich
# Atlantic/Faeroe
# PST8PDT
# Africa/Bangui
# Europe/Kaliningrad
# America/Punta_Arenas
# America/Montreal
# Etc/Universal
# America/Atikokan
# America/Maceio
# Etc/Zulu
# Africa/Brazzaville
# America/St_Vincent
# Brazil/West
# America/Adak
# Pacific/Fiji
# America/North_Dakota/Beulah
# Europe/London
# Europe/Vilnius
# MET
# Europe/Amsterdam
# Indian/Kerguelen
# America/Ojinaga
# Australia/Perth
# America/Indiana/Winamac
# Asia/Pyongyang
# Poland
# Mexico/BajaNorte
# Iceland
# Europe/Saratov
# America/Argentina/Rio_Gallegos
# Asia/Omsk
# Europe/Kiev
# Etc/GMT+8
# Pacific/Pohnpei
# Africa/Freetown
# Etc/GMT+10
# Etc/GMT0
# Mexico/BajaSur
# America/Swift_Current
# Antarctica/Troll
# Asia/Ashkhabad
# Europe/Belfast
# Etc/GMT+11
# Asia/Kuching
# Asia/Bangkok
# America/Guadeloupe
# America/Dawson_Creek
# Pacific/Guam
# Antarctica/Mawson
# America/Dawson
# Asia/Anadyr
# Africa/Abidjan
# Europe/Andorra
# US/Hawaii
# Etc/GMT+4
# Europe/Mariehamn
# GMT
# Canada/Atlantic
# America/Aruba
# Africa/Ouagadougou
# Africa/Nouakchott
# America/Blanc-Sablon
# Europe/Dublin
# America/El_Salvador
# Pacific/Norfolk
# Africa/Mogadishu
# Africa/Asmara
# Europe/Gibraltar
# America/Argentina/Ushuaia
# America/Ciudad_Juarez
# Pacific/Kosrae
# Asia/Kuala_Lumpur
# Africa/Ndjamena
# EST
# Europe/Uzhgorod
# US/Samoa
# Pacific/Apia
# Europe/Paris
# Asia/Hebron
# Asia/Tehran
# America/Argentina/Salta
# America/Belem
# America/Argentina/Buenos_Aires
# America/Argentina/ComodRivadavia
# America/Anchorage
# America/Thule
# America/Detroit
# America/Curacao
# Zulu
# Europe/Moscow
# Asia/Karachi
# US/Pacific
# Australia/Sydney
# UCT
# Australia/Broken_Hill
# America/Bahia
# America/Thunder_Bay
# Chile/EasterIsland
# Asia/Chungking
# America/New_York
# Europe/Brussels
# Africa/Nairobi
# America/Fortaleza
# Australia/South
# Australia/Yancowinna
# America/Cambridge_Bay
# ROC
# America/Miquelon
# Atlantic/Madeira
# Asia/Jerusalem
# Egypt
# Europe/Astrakhan
# Australia/Melbourne
# US/Mountain
# America/Guatemala
# Pacific/Wallis
# US/Alaska
# America/Santarem
# Turkey
# Europe/Zagreb
# Asia/Oral
# America/Inuvik
# Africa/Khartoum
# Europe/Bucharest
# Asia/Aqtau
# Europe/Samara
# Europe/Athens
# America/Yakutat
# Pacific/Chatham
# Atlantic/Bermuda
# America/North_Dakota/Center

# %%
from zoneinfo import ZoneInfo
zoneinfo = []
for time_zones in available_timezones():
    if 'Australia' in time_zones:
        zoneinfo.append(time_zones)
for zone_name in zoneinfo:
    print(zone_name)
# Out:
# Australia/Victoria
# Australia/LHI
# Australia/Lord_Howe
# Australia/ACT
# Australia/Canberra
# Australia/Adelaide
# Australia/Darwin
# Australia/Lindeman
# Australia/Tasmania
# Australia/Currie
# Australia/North
# Australia/Eucla
# Australia/West
# Australia/Queensland
# Australia/Hobart
# Australia/Brisbane
# Australia/NSW
# Australia/Perth
# Australia/Sydney
# Australia/Broken_Hill
# Australia/South
# Australia/Yancowinna
# Australia/Melbourne

# %%
from datetime import datetime
from zoneinfo import ZoneInfo

ivestas_laikas = input("Iveskite laika formatu HH:MM(:SS), sekundes nera butinos")
formatas = "%H:%M"
vartotojo_laiko_zona = input("iveskite laiko zona pvz.:\"America/Barbados\"")

if len(ivestas_laikas) > 5:
    formatas = "%H:%M:%S"
laikas = datetime.strptime(ivestas_laikas, formatas)

sydney = laikas.replace(tzinfo=ZoneInfo(vartotojo_laiko_zona)).astimezone(ZoneInfo("Australia/Sydney"))
dubai = laikas.replace(tzinfo=ZoneInfo(vartotojo_laiko_zona)).astimezone(ZoneInfo("Asia/Dubai"))
vilnius = laikas.replace(tzinfo=ZoneInfo(vartotojo_laiko_zona)).astimezone(ZoneInfo("Europe/Vilnius"))
london = laikas.replace(tzinfo=ZoneInfo(vartotojo_laiko_zona)).astimezone(ZoneInfo("Europe/London"))
new_york = laikas.replace(tzinfo=ZoneInfo(vartotojo_laiko_zona)).astimezone(ZoneInfo("America/New_York"))
los_angeles = laikas.replace(tzinfo=ZoneInfo(vartotojo_laiko_zona)).astimezone(ZoneInfo("America/Los_Angeles"))

print(f"""Jusu laikas: {laikas.time()}, {vartotojo_laiko_zona}
Sydnejaus laikas: {sydney.time()}, Australia/Sydney
Dubajaus laikas: {dubai.time()}, Asia/Dubai
Vilniaus laikas: {vilnius.time()}, Europe/Vilnius
Londono laikas: {london.time()}, Europe/London
New Yorko laikas: {new_york.time()}, America/New York
Los Angeles laikas: {los_angeles.time()}, America/ Los Angeles""")
# Out:
# Jusu laikas: 14:20:00, Europe/Moscow
# Sydnejaus laikas: 21:49:43, Australia/Sydney
# Dubajaus laikas: 15:30:55, Asia/Dubai
# Vilniaus laikas: 13:13:43, Europe/Vilnius
# Londono laikas: 11:49:43, Europe/London
# New Yorko laikas: 06:49:43, America/New York
# Los Angeles laikas: 03:49:43, America/ Los Angeles
