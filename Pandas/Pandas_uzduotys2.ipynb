# %% [markdown]
# # Pandas užduotys 2

# %%
import numpy as np
import pandas as pd
# Out:
# C:\Users\CodeAcademy\AppData\Local\Temp\ipykernel_10024\1662815981.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# #  1 Sulipdykite iš 4 fragmentų vieną lentelę:
#
# fragmentus rasite [čia](https://github.com/robotautas/kursas/tree/master/Pandas/tops)
#
# * top_left = pd.read_csv('top1-25-1.csv')
# * top_right = pd.read_csv('top1-25-2.csv')
# * bottom_left = pd.read_csv('top26-50-1.csv')
# * bottom_right = pd.read_csv('top26-50-2.csv')
#
# pirmiausiai sujunkite apatinę dalį, tada viršutinę *(yra persidengiančių stulpelių!)*, galiausiai viršų su apačia. Naudokite **.concat()** ir **.merge()** metodus.

# %%
top_left = pd.read_csv('tops/top1-25-1.csv')
top_right = pd.read_csv('tops/top1-25-2.csv')
bottom_left = pd.read_csv('tops/top26-50-1.csv')
bottom_right = pd.read_csv('tops/top26-50-2.csv')
data_bottom = pd.concat([bottom_left, bottom_right], axis = 1)
data_top = pd.merge(top_left, top_right, on=['Track.Name', 'Popularity'])
data = pd.concat([data_bottom, data_top])
data.head(50)
# Out:
#                                            Track.Name       Artist.Name  \
# 0                                 If I Can't Have You      Shawn Mendes
# 1                                        Dance Monkey       Tones and I
# 2                                            It's You         Ali Gatie
# 3                                           Con Calma      Daddy Yankee
# 4                                       QUE PRETENDES          J Balvin
# 5                                            Takeaway  The Chainsmokers
# 6                                             7 rings     Ariana Grande
# 7                                   0.958333333333333            Maluma
# 8           The London (feat. J. Cole & Travis Scott)        Young Thug
# 9                                   Never Really Over        Katy Perry
# 10  Summer Days (feat. Macklemore & Patrick Stump ...     Martin Garrix
# 11                                         Otro Trago              Sech
# 12                     Antisocial (with Travis Scott)        Ed Sheeran
# 13                                             Sucker    Jonas Brothers
# 14  fuck, i'm lonely (with Anne-Marie) - from 13 R...              Lauv
# 15                                        Higher Love              Kygo
# 16                              You Need To Calm Down      Taylor Swift
# 17                                            Shallow         Lady Gaga
# 18                                               Talk            Khalid
# 19                                         Con Altura           ROSALNA
# 20                                    One Thing Right        Marshmello
# 21                                           Te Robar         Nicky Jam
# 22                                            Happier        Marshmello
# 23                                      Call You Mine  The Chainsmokers
# 24      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 0                                            Senorita      Shawn Mendes
# 1                                               China          Anuel AA
# 2                       boyfriend (with Social House)     Ariana Grande
# 3                     Beautiful People (feat. Khalid)        Ed Sheeran
# 4                         Goodbyes (Feat. Young Thug)       Post Malone
# 5                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 6                                              Ransom         Lil Tecca
# 7                                   How Do You Sleep?         Sam Smith
# 8                               Old Town Road - Remix         Lil Nas X
# 9                                             bad guy     Billie Eilish
# 10                                           Callaita         Bad Bunny
# 11              Loco Contigo (feat. J. Balvin & Tyga)          DJ Snake
# 12                                  Someone You Loved     Lewis Capaldi
# 13                                 Otro Trago - Remix              Sech
# 14           Money In The Grave (Drake ft. Rick Ross)             Drake
# 15                          No Guidance (feat. Drake)       Chris Brown
# 16                                         LA CANCION          J Balvin
# 17      Sunflower - Spider-Man: Into the Spider-Verse       Post Malone
# 18                                             Lalala               Y2K
# 19                                        Truth Hurts             Lizzo
# 20                                Piece Of Your Heart            MEDUZA
# 21                                             Panini         Lil Nas X
# 22                               No Me Conoce - Remix       Jhay Cortez
# 23                                    Soltera - Remix             Lunay
# 24                       bad guy (with Justin Bieber)     Billie Eilish
#
#                Genre  Beats.Per.Minute  Energy  Danceability  Loudness..dB..  \
# 0       canadian pop               124      82            69              -4
# 1     australian pop                98      59            82              -6
# 2   canadian hip hop                96      46            73              -7
# 3              latin                94      86            74              -3
# 4              latin                93      79            64              -4
# 5                edm                85      51            29              -8
# 6          dance pop               140      32            78             -11
# 7          reggaeton                96      71            78              -5
# 8        atl hip hop                98      59            80              -7
# 9          dance pop               100      88            77              -5
# 10          big room               114      72            66              -7
# 11    panamanian pop               176      70            75              -5
# 12               pop               152      82            72              -5
# 13          boy band               138      73            84              -5
# 14         dance pop                95      56            81              -6
# 15               edm               104      68            69              -7
# 16         dance pop                85      68            77              -6
# 17         dance pop                96      39            57              -6
# 18               pop               136      40            90              -9
# 19    r&b en espanol                98      69            88              -4
# 20           brostep                88      62            66              -2
# 21             latin               176      75            67              -4
# 22           brostep               100      79            69              -3
# 23               edm               104      70            59              -6
# 24               NaN                95      79            75              -6
# 0       canadian pop               117      55            76              -6
# 1     reggaeton flow               105      81            79              -4
# 2          dance pop               190      80            40              -4
# 3                pop                93      65            64              -8
# 4            dfw rap               150      65            58              -4
# 5                pop               102      68            80              -5
# 6         trap music               180      64            75              -6
# 7                pop               111      68            48              -5
# 8        country rap               136      62            88              -6
# 9         electropop               135      43            70             -11
# 10         reggaeton               176      62            61              -5
# 11         dance pop                96      71            82              -4
# 12               pop               110      41            50              -6
# 13    panamanian pop               176      79            73              -2
# 14  canadian hip hop               101      50            83              -4
# 15         dance pop                93      45            70              -7
# 16             latin               176      65            75              -6
# 17           dfw rap                90      48            76              -6
# 18               NaN               130      39            84              -8
# 19       escape room               158      62            72              -3
# 20         pop house               124      74            68              -7
# 21       country rap               154      59            70              -6
# 22    reggaeton flow                92      79            81              -4
# 23             latin                92      78            80              -4
# 24        electropop               135      45            67             -11
#
#     Liveness  Valence.  Length.  Acousticness..  Speechiness.  Popularity
# 0         13        87      191              49             6        70.0
# 1         18        54      210              69            10        83.0
# 2         19        40      213              37             3        89.0
# 3          6        66      193              11             6        91.0
# 4         36        94      222               3            25        89.0
# 5         10        36      210              12             4        84.0
# 6          9        33      179              59            33        89.0
# 7          9        68      176              22            28        89.0
# 8         13        18      200               2            15        89.0
# 9         32        39      224              19             6        89.0
# 10        14        32      164              18             6        89.0
# 11        11        62      226              14            34        91.0
# 12        36        91      162              13             5        87.0
# 13        11        95      181               4             6        80.0
# 14         6        68      199              48             7        78.0
# 15        10        40      228               2             3        88.0
# 16         7        73      171               1             5        90.0
# 17        23        32      216              37             3        87.0
# 18         6        35      198               5            13        84.0
# 19         5        75      162              39            12        88.0
# 20        58        44      182               7             5        88.0
# 21         8        80      202              24             6        88.0
# 22        17        67      214              19             5         NaN
# 23        41        50      218              23             3        88.0
# 24         7        61      206              21            12        82.0
# 0          8        75      191               4             3        79.0
# 1          8        61      302               8             9        92.0
# 2         16        70      186              12            46        85.0
# 3          8        55      198              12            19         NaN
# 4         11        18      175              45             7        94.0
# 5          9        84      220               9             4        84.0
# 6          7        23      131               2            29        92.0
# 7          8        35      202              15             9        90.0
# 8         11        64      157               5            10        87.0
# 9         10        56      194              33            38        95.0
# 10        24        24      251              60            31        93.0
# 11        15        38      185              28             7        86.0
# 12        11        45      182              75             3        88.0
# 13         6        76      288               7            20        87.0
# 14        12        10      205              10             5        92.0
# 15        16        14      261              12            15        82.0
# 16        11        43      243              15            32        90.0
# 17         7        91      158              56             5        91.0
# 18        14        50      161              18             8        88.0
# 19        12        41      173              11            11        91.0
# 20         7        63      153               4             3        91.0
# 21        12        48      115              34             8        91.0
# 22         9        58      309              14             7        83.0
# 23        44        80      266              36             4        91.0
# 24        12        68      195              25            30         NaN

# %%
# Out:
#                         Track.Name    Artist.Name           Genre  Popularity  \
# 0                         Senorita   Shawn Mendes    canadian pop        79.0
# 1                            China       Anuel AA  reggaeton flow        92.0
# 2    boyfriend (with Social House)  Ariana Grande       dance pop        85.0
# 3  Beautiful People (feat. Khalid)     Ed Sheeran             pop         NaN
# 4      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap        94.0
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.
# 0      191               4             3
# 1      302               8             9
# 2      186              12            46
# 3      198              12            19
# 4      175              45             7

# %% [markdown]
# # 2 Sutvarkykite indeksą - padarykite, kad prasidėtų nuo 1.

# %%
data['NR']= list(range(1,51))
data.set_index('NR', inplace=True)
data.head(26)
# Out:
#                                            Track.Name       Artist.Name  \
# NR
# 1                                 If I Can't Have You      Shawn Mendes
# 2                                        Dance Monkey       Tones and I
# 3                                            It's You         Ali Gatie
# 4                                           Con Calma      Daddy Yankee
# 5                                       QUE PRETENDES          J Balvin
# 6                                            Takeaway  The Chainsmokers
# 7                                             7 rings     Ariana Grande
# 8                                   0.958333333333333            Maluma
# 9           The London (feat. J. Cole & Travis Scott)        Young Thug
# 10                                  Never Really Over        Katy Perry
# 11  Summer Days (feat. Macklemore & Patrick Stump ...     Martin Garrix
# 12                                         Otro Trago              Sech
# 13                     Antisocial (with Travis Scott)        Ed Sheeran
# 14                                             Sucker    Jonas Brothers
# 15  fuck, i'm lonely (with Anne-Marie) - from 13 R...              Lauv
# 16                                        Higher Love              Kygo
# 17                              You Need To Calm Down      Taylor Swift
# 18                                            Shallow         Lady Gaga
# 19                                               Talk            Khalid
# 20                                         Con Altura           ROSALNA
# 21                                    One Thing Right        Marshmello
# 22                                           Te Robar         Nicky Jam
# 23                                            Happier        Marshmello
# 24                                      Call You Mine  The Chainsmokers
# 25      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 26                                           Senorita      Shawn Mendes
#
#                Genre  Beats.Per.Minute  Energy  Danceability  Loudness..dB..  \
# NR
# 1       canadian pop               124      82            69              -4
# 2     australian pop                98      59            82              -6
# 3   canadian hip hop                96      46            73              -7
# 4              latin                94      86            74              -3
# 5              latin                93      79            64              -4
# 6                edm                85      51            29              -8
# 7          dance pop               140      32            78             -11
# 8          reggaeton                96      71            78              -5
# 9        atl hip hop                98      59            80              -7
# 10         dance pop               100      88            77              -5
# 11          big room               114      72            66              -7
# 12    panamanian pop               176      70            75              -5
# 13               pop               152      82            72              -5
# 14          boy band               138      73            84              -5
# 15         dance pop                95      56            81              -6
# 16               edm               104      68            69              -7
# 17         dance pop                85      68            77              -6
# 18         dance pop                96      39            57              -6
# 19               pop               136      40            90              -9
# 20    r&b en espanol                98      69            88              -4
# 21           brostep                88      62            66              -2
# 22             latin               176      75            67              -4
# 23           brostep               100      79            69              -3
# 24               edm               104      70            59              -6
# 25               NaN                95      79            75              -6
# 26      canadian pop               117      55            76              -6
#
#     Liveness  Valence.  Length.  Acousticness..  Speechiness.  Popularity
# NR
# 1         13        87      191              49             6        70.0
# 2         18        54      210              69            10        83.0
# 3         19        40      213              37             3        89.0
# 4          6        66      193              11             6        91.0
# 5         36        94      222               3            25        89.0
# 6         10        36      210              12             4        84.0
# 7          9        33      179              59            33        89.0
# 8          9        68      176              22            28        89.0
# 9         13        18      200               2            15        89.0
# 10        32        39      224              19             6        89.0
# 11        14        32      164              18             6        89.0
# 12        11        62      226              14            34        91.0
# 13        36        91      162              13             5        87.0
# 14        11        95      181               4             6        80.0
# 15         6        68      199              48             7        78.0
# 16        10        40      228               2             3        88.0
# 17         7        73      171               1             5        90.0
# 18        23        32      216              37             3        87.0
# 19         6        35      198               5            13        84.0
# 20         5        75      162              39            12        88.0
# 21        58        44      182               7             5        88.0
# 22         8        80      202              24             6        88.0
# 23        17        67      214              19             5         NaN
# 24        41        50      218              23             3        88.0
# 25         7        61      206              21            12        82.0
# 26         8        75      191               4             3        79.0

# %%
# Out:
#                         Track.Name    Artist.Name           Genre  Popularity  \
# #
# 1                         Senorita   Shawn Mendes    canadian pop        79.0
# 2                            China       Anuel AA  reggaeton flow        92.0
# 3    boyfriend (with Social House)  Ariana Grande       dance pop        85.0
# 4  Beautiful People (feat. Khalid)     Ed Sheeran             pop         NaN
# 5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap        94.0
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# #
# 1               117      55            76              -6         8        75
# 2               105      81            79              -4         8        61
# 3               190      80            40              -4        16        70
# 4                93      65            64              -8         8        55
# 5               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.
# #
# 1      191               4             3
# 2      302               8             9
# 3      186              12            46
# 4      198              12            19
# 5      175              45             7

# %% [markdown]
# # 3 Sukurkite grupavimo pagal žanrą objektą

# %%
grouped = data.groupby(['Genre'])
grouped

# %% [markdown]
# # 4 kokie žanrai lentelėje pasitaiko daugiau negu 3 kartus?

# %%
new_data = grouped.count()
new_data
# Out:
#                   Track.Name  Artist.Name  Beats.Per.Minute  Energy  \
# Genre
# atl hip hop                1            1                 1       1
# australian pop             1            1                 1       1
# big room                   1            1                 1       1
# boy band                   1            1                 1       1
# brostep                    2            2                 2       2
# canadian hip hop           2            2                 2       2
# canadian pop               2            2                 2       2
# country rap                2            2                 2       2
# dance pop                  8            8                 8       8
# dfw rap                    2            2                 2       2
# edm                        3            3                 3       3
# electropop                 2            2                 2       2
# escape room                1            1                 1       1
# latin                      5            5                 5       5
# panamanian pop             2            2                 2       2
# pop                        6            6                 6       6
# pop house                  1            1                 1       1
# r&b en espanol             1            1                 1       1
# reggaeton                  2            2                 2       2
# reggaeton flow             2            2                 2       2
# trap music                 1            1                 1       1
#
#                   Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# Genre
# atl hip hop                  1               1         1         1        1
# australian pop               1               1         1         1        1
# big room                     1               1         1         1        1
# boy band                     1               1         1         1        1
# brostep                      2               2         2         2        2
# canadian hip hop             2               2         2         2        2
# canadian pop                 2               2         2         2        2
# country rap                  2               2         2         2        2
# dance pop                    8               8         8         8        8
# dfw rap                      2               2         2         2        2
# edm                          3               3         3         3        3
# electropop                   2               2         2         2        2
# escape room                  1               1         1         1        1
# latin                        5               5         5         5        5
# panamanian pop               2               2         2         2        2
# pop                          6               6         6         6        6
# pop house                    1               1         1         1        1
# r&b en espanol               1               1         1         1        1
# reggaeton                    2               2         2         2        2
# reggaeton flow               2               2         2         2        2
# trap music                   1               1         1         1        1
#
#                   Acousticness..  Speechiness.  Popularity
# Genre
# atl hip hop                    1             1           1
# australian pop                 1             1           1
# big room                       1             1           1
# boy band                       1             1           1
# brostep                        2             2           1
# canadian hip hop               2             2           2
# canadian pop                   2             2           2
# country rap                    2             2           2
# dance pop                      8             8           8
# dfw rap                        2             2           2
# edm                            3             3           3
# electropop                     2             2           1
# escape room                    1             1           1
# latin                          5             5           5
# panamanian pop                 2             2           2
# pop                            6             6           5
# pop house                      1             1           1
# r&b en espanol                 1             1           1
# reggaeton                      2             2           2
# reggaeton flow                 2             2           2
# trap music                     1             1           1

# %%
# Out:
#                 Track.Name  Artist.Name  Popularity  Beats.Per.Minute  Energy  \
# Genre
# atl hip hop              1            1           1                 1       1
# australian pop           1            1           1                 1       1
# big room                 1            1           1                 1       1
# boy band                 1            1           1                 1       1
# brostep                  2            2           1                 2       2
#
#                 Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# Genre
# atl hip hop                1               1         1         1        1
# australian pop             1               1         1         1        1
# big room                   1               1         1         1        1
# boy band                   1               1         1         1        1
# brostep                    2               2         2         2        2
#
#                 Acousticness..  Speechiness.
# Genre
# atl hip hop                  1             1
# australian pop               1             1
# big room                     1             1
# boy band                     1             1
# brostep                      2             2

# %%
new_data[new_data['Track.Name']>3]#['Energy']
# Out:
#            Track.Name  Artist.Name  Beats.Per.Minute  Energy  Danceability  \
# Genre
# dance pop           8            8                 8       8             8
# latin               5            5                 5       5             5
# pop                 6            6                 6       6             6
#
#            Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  \
# Genre
# dance pop               8         8         8        8               8
# latin                   5         5         5        5               5
# pop                     6         6         6        6               6
#
#            Speechiness.  Popularity
# Genre
# dance pop             8           8
# latin                 5           5
# pop                   6           5

# %%
new_data[new_data >3]
# Out:
#                   Track.Name  Artist.Name  Beats.Per.Minute  Energy  \
# Genre
# atl hip hop              NaN          NaN               NaN     NaN
# australian pop           NaN          NaN               NaN     NaN
# big room                 NaN          NaN               NaN     NaN
# boy band                 NaN          NaN               NaN     NaN
# brostep                  NaN          NaN               NaN     NaN
# canadian hip hop         NaN          NaN               NaN     NaN
# canadian pop             NaN          NaN               NaN     NaN
# country rap              NaN          NaN               NaN     NaN
# dance pop                8.0          8.0               8.0     8.0
# dfw rap                  NaN          NaN               NaN     NaN
# edm                      NaN          NaN               NaN     NaN
# electropop               NaN          NaN               NaN     NaN
# escape room              NaN          NaN               NaN     NaN
# latin                    5.0          5.0               5.0     5.0
# panamanian pop           NaN          NaN               NaN     NaN
# pop                      6.0          6.0               6.0     6.0
# pop house                NaN          NaN               NaN     NaN
# r&b en espanol           NaN          NaN               NaN     NaN
# reggaeton                NaN          NaN               NaN     NaN
# reggaeton flow           NaN          NaN               NaN     NaN
# trap music               NaN          NaN               NaN     NaN
#
#                   Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# Genre
# atl hip hop                NaN             NaN       NaN       NaN      NaN
# australian pop             NaN             NaN       NaN       NaN      NaN
# big room                   NaN             NaN       NaN       NaN      NaN
# boy band                   NaN             NaN       NaN       NaN      NaN
# brostep                    NaN             NaN       NaN       NaN      NaN
# canadian hip hop           NaN             NaN       NaN       NaN      NaN
# canadian pop               NaN             NaN       NaN       NaN      NaN
# country rap                NaN             NaN       NaN       NaN      NaN
# dance pop                  8.0             8.0       8.0       8.0      8.0
# dfw rap                    NaN             NaN       NaN       NaN      NaN
# edm                        NaN             NaN       NaN       NaN      NaN
# electropop                 NaN             NaN       NaN       NaN      NaN
# escape room                NaN             NaN       NaN       NaN      NaN
# latin                      5.0             5.0       5.0       5.0      5.0
# panamanian pop             NaN             NaN       NaN       NaN      NaN
# pop                        6.0             6.0       6.0       6.0      6.0
# pop house                  NaN             NaN       NaN       NaN      NaN
# r&b en espanol             NaN             NaN       NaN       NaN      NaN
# reggaeton                  NaN             NaN       NaN       NaN      NaN
# reggaeton flow             NaN             NaN       NaN       NaN      NaN
# trap music                 NaN             NaN       NaN       NaN      NaN
#
#                   Acousticness..  Speechiness.  Popularity
# Genre
# atl hip hop                  NaN           NaN         NaN
# australian pop               NaN           NaN         NaN
# big room                     NaN           NaN         NaN
# boy band                     NaN           NaN         NaN
# brostep                      NaN           NaN         NaN
# canadian hip hop             NaN           NaN         NaN
# canadian pop                 NaN           NaN         NaN
# country rap                  NaN           NaN         NaN
# dance pop                    8.0           8.0         8.0
# dfw rap                      NaN           NaN         NaN
# edm                          NaN           NaN         NaN
# electropop                   NaN           NaN         NaN
# escape room                  NaN           NaN         NaN
# latin                        5.0           5.0         5.0
# panamanian pop               NaN           NaN         NaN
# pop                          6.0           6.0         5.0
# pop house                    NaN           NaN         NaN
# r&b en espanol               NaN           NaN         NaN
# reggaeton                    NaN           NaN         NaN
# reggaeton flow               NaN           NaN         NaN
# trap music                   NaN           NaN         NaN

# %% [markdown]
# # 5 Koks žanras pats populiariausias? Koks mažiausiai populiarus?
# (pagal populiarumo vidurkį)

# %%
# Out:
# electropop 95.0
# canadian pop 74.5

# %%
most_p_g = grouped['Popularity'].mean().idxmax()
most_p_s = grouped['Popularity'].mean().max()
most_p_g, most_p_s
# Out:
# ('electropop', 95.0)

# %% [markdown]
# # 6 Sukurkite lentelę, kurioje matytųsi, koks žanras turi aukščiausią vidurkį kiekviename indikatoriuje, bei pats vidurkis.
# kad nereikėtų daug vargti su stulpelių pavadinimais, galima juos ištraukti su **.columns.tolist()**

# %%
# Out:
#        Indikatorius          Žanras  Balai
# 0        Popularity      electropop     95
# 1  Beats.Per.Minute      trap music    180
# 2            Energy  reggaeton flow     80
# 3      Danceability  r&b en espanol     88
# 4    Loudness..dB..         brostep   -2.5
# 5          Liveness         brostep   37.5
# 6          Valence.        boy band     95
# 7           Length.  reggaeton flow  305.5
# 8    Acousticness..  australian pop     69
# 9      Speechiness.      electropop     34

# %% [markdown]
# # 7 Grįžkime prie sulipdytos lentelės. Ištraukite visas eilutes, kurios turi NaN reikšmių.
# *filtravimo sąlygose naudokite **.isnull()** funkciją.*

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 50
# Data columns (total 13 columns):
# Track.Name          50 non-null object
# Artist.Name         50 non-null object
# Genre               48 non-null object
# Popularity          47 non-null float64
# Beats.Per.Minute    50 non-null int64
# Energy              50 non-null int64
# Danceability        50 non-null int64
# Loudness..dB..      50 non-null int64
# Liveness            50 non-null int64
# Valence.            50 non-null int64
# Length.             50 non-null int64
# Acousticness..      50 non-null int64
# Speechiness.        50 non-null int64
# dtypes: float64(1), int64(9), object(3)
# memory usage: 5.5+ KB

# %%
# Out:
#                                        Track.Name    Artist.Name       Genre  \
# #
# 4                 Beautiful People (feat. Khalid)     Ed Sheeran         pop
# 19                                         Lalala            Y2K         NaN
# 25                   bad guy (with Justin Bieber)  Billie Eilish  electropop
# 48                                        Happier     Marshmello     brostep
# 50  Cross Me (feat. Chance the Rapper & PnB Rock)     Ed Sheeran         NaN
#
#     Popularity  Beats.Per.Minute  Energy  Danceability  Loudness..dB..  \
# #
# 4          NaN                93      65            64              -8
# 19        88.0               130      39            84              -8
# 25         NaN               135      45            67             -11
# 48         NaN               100      79            69              -3
# 50        82.0                95      79            75              -6
#
#     Liveness  Valence.  Length.  Acousticness..  Speechiness.
# #
# 4          8        55      198              12            19
# 19        14        50      161              18             8
# 25        12        68      195              25            30
# 48        17        67      214              19             5
# 50         7        61      206              21            12

# %% [markdown]
# # 8 Stulpelyje 'Genre' NaN reikšmes pakeiskite į 'pop'

# %% [markdown]
# # 9 Stulpelyje 'Popularity' trūkstamas reikšmes pakeiskite į stulpelio vidurkį
